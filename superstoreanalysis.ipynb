# %%
#Importing numpy library
import numpy as np

# %%
#Importing pandas library
import pandas as pd

# %%
#import harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#Importing matplotlib library
import matplotlib.pyplot as plt

# %%
#Importing seaborn library
import seaborn as sns

# %%
#To Display all the columns in the dataset
pd.set_option("display.max_columns",None)

# %%
#To display all the rows in the dataset
pd.set_option("display.max_rows",None)

# %%
#Loading the sample Super Store Dataset
data=pd.read_csv("SampleSuperstore.csv")
print(data)
# Out:
#            Ship Mode      Segment        Country               City  \
# 0       Second Class     Consumer  United States          Henderson
# 1       Second Class     Consumer  United States          Henderson
# 2       Second Class    Corporate  United States        Los Angeles
# 3     Standard Class     Consumer  United States    Fort Lauderdale
# 4     Standard Class     Consumer  United States    Fort Lauderdale
# 5     Standard Class     Consumer  United States        Los Angeles
# 6     Standard Class     Consumer  United States        Los Angeles
# 7     Standard Class     Consumer  United States        Los Angeles
# 8     Standard Class     Consumer  United States        Los Angeles
# 9     Standard Class     Consumer  United States        Los Angeles
# 10    Standard Class     Consumer  United States        Los Angeles
# 11    Standard Class     Consumer  United States        Los Angeles
# 12    Standard Class     Consumer  United States            Concord
# ...

# %%
#To display the first 5 rows of the superstore datset
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
#To display the last 5 rows of the superstore dataset 
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
#To get the information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#to describe about the dataset
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#To know the datatypes of each column 
data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
#To display the null values count im each column
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#To know the columns whose data type is object
n=data.columns[data.dtypes =='object']
print(n)
#To know the columns whose datatype is float 64
n1=data.columns[data.dtypes=='float64']
print(n1)
#To know the columns whose datatype is int 32
n2=data.columns[data.dtypes=='int64']
print(n2)
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category'],
#       dtype='object')
# Index(['Sales', 'Discount', 'Profit'], dtype='object')
# Index(['Postal Code', 'Quantity'], dtype='object')

# %%
#fnd the ship mode by  count
data["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
#find the segment by count
data["Segment"].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
#find the different countries by count
data["Country"].value_counts()
# Out:
# Country
# United States    9994
# Name: count, dtype: int64

# %%
#find the different cities by count
data["City"].value_counts()
# Out:
# City
# New York City        915
# Los Angeles          747
# Philadelphia         537
# San Francisco        510
# Seattle              428
# Houston              377
# Chicago              314
# Columbus             222
# San Diego            170
# Springfield          163
# Dallas               157
# Jacksonville         125
# Detroit              115
# Newark                95
# Richmond              90
# Jackson               82
# Columbia              81
# Aurora                68
# Phoenix               63
# Long Beach            61
# Arlington             60
# San Antonio           59
# Miami                 57
# Louisville            57
# Rochester             53
# Charlotte             52
# Henderson             51
# Lakewood              49
# Lancaster             46
# Fairfield             45
# Milwaukee             45
# Denver                44
# Lawrence              44
# Baltimore             43
# Cleveland             42
# Pasadena              42
# ...

# %%
#Visualizing the superstore datset
#sales analysis based on region using barchart
data.groupby("Region")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
#profit analysis based on region using barchart
data.groupby("Region")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
#sales analysis based on region using pie chart
data.groupby("Region")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
#profit analysis based on region using pie chart
data.groupby("Region")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
#sales analysis based on segment using bar chart
data.groupby("Segment")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
#profit analysis based on segment using barchart
data.groupby("Segment")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
#sales analysis based on segment using piechart
data.groupby("Segment")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
#profit analysis based on segment using pie chart
data.groupby("Segment")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
#sales analysis based on category using bar chart
data.groupby("Category")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
#profit analysis based on Category using barchart
data.groupby("Category")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
#sales analysis based on Category using pie chart
data.groupby("Category")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
#profit analysis based on Category using piechart
data.groupby("Category")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
#sales analysis based on state using barchart
data.groupby("State")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
#profit analysis based on state using barchart
data.groupby("State")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
#sales analysis based on ship mode using barchart
data.groupby("Ship Mode")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Ship Mode'>

# %%
#profit analysis based on shipmode using bar chart
data.groupby("Ship Mode")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Ship Mode'>

# %%
#sales analysis based on ship mode using pie chart
data.groupby("Ship Mode")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
#profit analysis based on ship mode using pie chart
data.groupby("Ship Mode")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
import missingno as msno
msno.bar(data)
# Out:
# <Axes: >
